# %% [markdown]
# # Esse é o meu titulo
#  essa inha cria uma variavel `a`.

# %%
a=2

# %%
a
# Out:
# 2

# %% [markdown]
# Essa linha tem o valor da variável `a` em dobro

# %%
b = a * 2  # 4
b
# Out:
# 4

# %% [markdown]
# Essa linha mostra o valor de `a` + `b`

# %%
print(a + b)  # 6
# Out:
# 6
